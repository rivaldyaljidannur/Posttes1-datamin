# %% [markdown]
# <a href="https://colab.research.google.com/github/rivaldyaljidannur/Posttes1-datamin/blob/main/posttest1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Posttest 1
#
# ### Andi Muhammad Rivaldy Aljidannur
# ### 2109116097

# %% [markdown]
# #Library

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# Business Understanding & Data Understanding

# %% [markdown]
# #Business Understanding

# %%
df= pd.read_csv('https://raw.githubusercontent.com/fnikolas-r/Data-Mining-Course/main/Pertemuan%202/ChurnBank.csv')
df
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# ...

# %% [markdown]
# #Data Understanding

# %%
#  df1 isinya dataset dengan label target AttiredCustomer
df1 = df[df["Attrition_Flag"] == "Attrited Customer"]
df1
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0        6036  720010608  Attrited Customer            37      M
# 1        6684  711323283  Attrited Customer            57      M
# 2        4272  794707083  Attrited Customer            50      M
# 3        9759  709657533  Attrited Customer            44      M
# 4        4740  716625033  Attrited Customer            32      F
# 5        9597  715076358  Attrited Customer            57      M
# 6        5009  804829533  Attrited Customer            59      M
# 7        8200  712144158  Attrited Customer            53      F
# 8        5016  795599883  Attrited Customer            57      F
# 9        8350  709222008  Attrited Customer            41      M
#
#   Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0         Unknown         Single     $40K - $60K          Blue       10226.0
# 1      Uneducated        Married     $60K - $80K          Blue        2527.0
# ...

# %%
#df2 dengan label bukan Attrired customer
df2 = df[df["Attrition_Flag"] != "Attrited Customer"]
df2
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 11      Uneducated        Married    $80K - $120K          Blue       26792.0
# ...

# %%
# df3 dengan tabel untuk usia dibawah 50 tahun
df3 = df[df["Customer_Age"]<50]
df3
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# ...

# %%
# df4 untuk customer yang statusnya itu single
df4 = df[df["Marital_Status"] == "Single" ]
df4
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 2         4272  794707083  Attrited Customer            50      M
# 4         4740  716625033  Attrited Customer            32      F
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# ...

# %%
# Tampilkan info dataset (df.info()) dan berikan penjelasannya dalam bentuk teks atau comment
from pandas.io.formats import info

df,info

#Data tersebut adalah sebuah tabel yg digunakan dalam analisis data.
#Kolom-kolom terdapat di bawah adalah:

#Unnamed 0       : merupakan indeks dari setiap baris, yang mungkin sudah diberikan indeks oleh sistem atau program lainnya.
#CLIENTNUM: nomor identifikasi unik untuk setiap pelanggan.
#Attrition_Flag  : variabel biner yang menunjukkan apakah pelanggan sudah meninggalkan perusahaan (Attrited Customer) atau masih menjadi pelanggan (Existing Customer).
#Customer_Age: umur pelanggan dalam tahun.
#Gender          : jenis kelamin pelanggan (M untuk laki-laki dan F untuk perempuan).
#Education_Level : menunjukkan tingkat pendidikan pengguna kartu kredit, yang terdiri dari lima kategori yaitu "Unknown", "Uneducated", "College", "High School", dan "Post-Graduate".
#Marital_Status  : menunjukkan status perkawinan pengguna kartu kredit, yang terdiri dari tiga kategori yaitu "Single", "Married", dan "Unknown".
#Income_Category : menunjukkan kategori penghasilan pengguna kartu kredit, yang terdiri dari lima kategori yaitu "Less than $40K", "$40K - $60K", "$60K - $80K", "$80K - $120K", dan "$120K+".
#Card_Category   : menunjukkan jenis kartu kredit yang dimiliki oleh pengguna, yang terdiri dari empat kategori yaitu "Blue", "Silver", "Gold", dan "Platinum".
#Credit_Limit    : menunjukkan batas kredit yang diberikan kepada pengguna kartu kredit.
# Out:
# (    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
#  0         6036  720010608  Attrited Customer            37      M
#  1         6684  711323283  Attrited Customer            57      M
#  2         4272  794707083  Attrited Customer            50      M
#  3         9759  709657533  Attrited Customer            44      M
#  4         4740  716625033  Attrited Customer            32      F
#  5         9597  715076358  Attrited Customer            57      M
#  6         5009  804829533  Attrited Customer            59      M
#  7         8200  712144158  Attrited Customer            53      F
#  8         5016  795599883  Attrited Customer            57      F
#  9         8350  709222008  Attrited Customer            41      M
#  10        8139  809844108  Existing Customer            48      M
#  11         176  716264358  Existing Customer            53      M
#  12        8020  778163508  Existing Customer            37      F
# ...

# %% [markdown]
# #Opsional 1 (Mencari rata" , Min, Max dan Standar Deviansi)

# %%
rata_rata = df['Unnamed: 0'].mean()

nilai_min = df['Unnamed: 0'].min()

nilai_max = df['Unnamed: 0'].max()

std_deviasi = df['Unnamed: 0'].std()

# %%
rata_rata
# Out:
# 6105.1

# %%
nilai_min
# Out:
# 176

# %%
nilai_max
# Out:
# 10084

# %%
std_deviasi
# Out:
# 2850.304026258473

# %% [markdown]
# #EXPLORE DATA

# %%
#menampilkan berapa banyak yang attired customer dan tidak
sns.countplot(data=df, x="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
# Data diatas Menunjukkan  Attried Customer dan Existing Customer memiliki 10 data dari total 20 data

# %%
#menampilkan berapa banyak Education level berdasarkan kategori-kategorinya 
px.pie(df, names = "Education_Level")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# dari 20 data diatas, anggota yang memiliki education nya Graduated dan Uneducated memliki data yang tertinggi yaitu 25%
# sedangkan yang anggota education doctorate dan College yang tersedikit yaitu  5%

# %%
#menampilkan berapa banyak Education level berdasarkan gendernya
sns.countplot(data=df,x='Gender', hue='Education_Level')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
#dari data diatas, anggota yang memiliki eduaction Graduate paling banyak dimiliki oleh anggota yang bergender F,
# sedangkan education uneducated paling banyaj bergender M

# %% [markdown]
# ###Visualisasi Distribution

# %%
#historgram untuk customer dan credit card limit
sns.histplot(data = df, x="Customer_Age",kde = True)
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Count'>

# %%
sns.histplot(data = df, x="Credit_Limit", kde = True)
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Count'>

# %%
# Boxplot
sns.boxplot(y='Attrition_Flag', x='Credit_Limit', data=df)
plt.show()

# %% [markdown]
# ###Visualisasi Relationship

# %%
#scatterplot untuk umur customer dan credit card limit
sns.scatterplot(x='Customer_Age', y='Credit_Limit', data=df)
plt.show()

# %% [markdown]
# ###Visualisasi Composition

# %%
#pieplot untuk Income Category & Education Level
px.pie(df,names="Income_Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#dari data di atas income category kurang dari $40k memiliki data 25%, income category $60k-$80k memiliki data 25%, income category $80k-$120k memliki data 20%
#income category uknown memiliki data 20%, income category $120k+ memiliki data 5% dan income category $40k-$60k memiliki data 5% juga

# %%
px.pie(df,names="Education_Level")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#dari data di atas education level graduate memiliki data 25%, education level uneducated memiliki data 25%, education level high school memliki data 20%
#education level uknown memiliki data 10%, education level post graduate memiliki data 10%, education level college memiliki data 5%, education level doctorate memiliki data 5%

# %% [markdown]
# ##Algoritma Naive Bayes

# %%
# hapus data sesuai ketentuan
data_train = df.drop(["Unnamed: 0", "CLIENTNUM", "Customer_Age", "Credit_Limit"], axis=1)

# memindah  attrition_flag ke ujung kanan
cols = data_train.columns.tolist()
cols.remove('Attrition_Flag')
cols.append('Attrition_Flag')
data_train = data_train[cols]


# Menghitung jumlah data training dan data testing
N_train = len(data_train)

# Menghitung jumlah kelas target
target_counts = data_train.groupby('Attrition_Flag')['Attrition_Flag'].count()

# Menghitung probabilitas priori  setiap kelas target
prior_prob = target_counts / N_train

# Menghitung probabilitas kondisional  setiap fitur pada setiap kelas target
cond_prob = {}
for col in data_train.columns[:-1]:
    cond_prob[col] = {}
    for val in data_train[col].unique():
        for target in data_train['Attrition_Flag'].unique():
            count = len(data_train[(data_train[col] == val) & (data_train['Attrition_Flag'] == target)])
            cond_prob[col][(val, target)] = count / target_counts[target]
            

# Fungsi 
def naive_bayes(x):
    prob_yes = prior_prob['Attrited Customer']
    prob_no = prior_prob['Existing Customer']
    for i, col in enumerate(data_train.columns[:-1]):
        prob_yes *= cond_prob[col][(x[i], 'Attrited Customer')]
        prob_no *= cond_prob[col][(x[i], 'Existing Customer')]
    if prob_no > prob_yes:
        return ('Existing Customer', float(prob_no))
    else:
        return ('Attrited Customer', float(prob_yes))
# Contoh penggunaan fungsi naive_bayes
result = naive_bayes(["F",	"Uneducated","Single", "Unknown",	"Blue"])
result
# Out:
# ('Existing Customer', 0.0135)
